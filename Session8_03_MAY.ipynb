# %%
import pandas as pd
df=pd.read_excel(r"D:\Desktop\New folder\Book1.xlsx")

# %%
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment    DOB  AGE  ...        Product ID  \
# 0       Rick Hansen     Consumer  36363  NaN  ...   TEC-AC-10003033
# 1     Justin Ritter    Corporate  32057  NaN  ...   FUR-CH-10003950
# 2      Craig Reiter     Consumer  24725  NaN  ...   TEC-PH-10004664
# 3  Katherine Murray  Home Office  25929  NaN  ...   TEC-PH-10004583
# 4       Rick Hansen     Consumer  28240  NaN  ...  TEC-SHA-10000501
#
#      Category Sub-Category                                       Product Name  \
# ...

# %%
df.isnull().sum().sum()
# Out:
# 92586

# %%
#category=Technology, segment=Consumer , Sales>2000 and age> 30 and less than 40

# %%
df1=df[(df['Category']=="Technology") & (df['Segment']=='Consumer') & (df['Sales']>2000)].head().reset_index()
df1
# Out:
#    index  Row ID        Order ID Order Date  Ship Date     Ship Mode  \
# 0      0   32298  CA-2012-124891 2012-07-31 2012-07-31      Same Day
# 1      2   25330   IN-2013-71249 2013-10-17 2013-10-18   First Class
# 2      4   47221    SG-2013-4320 2013-11-05 2013-11-06      Same Day
# 3     12   45794    SA-2011-1830 2011-12-27 2011-12-29  Second Class
# 4     21   31784  CA-2011-154627 2011-10-29 2011-10-31   First Class
#
#   Customer ID    Customer Name   Segment    DOB  ...        Product ID  \
# 0    RH-19495      Rick Hansen  Consumer  36363  ...   TEC-AC-10003033
# 1    CR-12730     Craig Reiter  Consumer  24725  ...   TEC-PH-10004664
# 2     RH-9495      Rick Hansen  Consumer  28240  ...  TEC-SHA-10000501
# 3     MM-7260  Magdelene Morse  Consumer  26282  ...  TEC-CIS-10001717
# 4    SA-20830     Sue Ann Reed  Consumer  27763  ...   TEC-PH-10001363
#
#      Category Sub-Category                                       Product Name  \
# ...

# %%
df['new_qty']=df[Quantity]+7

# %%
# profit>3000- Hight profit
# profit>1000 and < 3000 mid_profit
# profit <1000 then less_profit
# Out:
# 8399.976

# %%
df['Profit_tag']="Hight_profit"
df['Profit_tag'][df['Profit'].between(1000,3000)]="Mid_profit"
df['Profit_tag'][df['Profit']<1000]="Less_profit"

df['Profit_tag'].value_counts()
# Out:
# C:\Users\91824\AppData\Local\Temp\ipykernel_3412\876421222.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Profit_tag'][df['Profit'].between(1000,3000)]="Mid_profit"
# C:\Users\91824\AppData\Local\Temp\ipykernel_3412\876421222.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Profit_tag'][df['Profit']<1000]="Less_profit"
# Less_profit     51143
# Mid_profit        139
# Hight_profit        8
# Name: Profit_tag, dtype: int64

# %%
df['Profit_tag1']="Less_profit"
df['Profit_tag1'][df['Profit']>3000]="High_profit"
df['Profit_tag1'][df['Profit'].between(1000,3000)]="mid_profit"
df
# Out:
# C:\Users\91824\AppData\Local\Temp\ipykernel_3412\856841263.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Profit_tag1'][df['Profit']>3000]="High_profit"
# C:\Users\91824\AppData\Local\Temp\ipykernel_3412\856841263.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Profit_tag1'][df['Profit'].between(1000,3000)]="mid_profit"
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# ...

# %%
# profit>3000 --"HIGH"
# Profit<3000---LOW
df['new_profit3']="High"
df['new_profit3'][df['Profit']<3000]="Low"
df
# Out:
# C:\Users\91824\AppData\Local\Temp\ipykernel_3412\2576625800.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['new_profit3'][df['Profit']<3000]="Low"
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# ...

# %%
import numpy as np

# %%
df['new_profit4']=np.where(df['Profit']>3000,"High","Low")
df
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment    DOB  AGE  ...     Sales  \
# ...

# %%
df2=df.drop(['Profit_tag1','new_profit3','new_profit4'],axis=1)
df2
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment    DOB  AGE  ...  \
# 0        RH-19495       Rick Hansen     Consumer  36363  NaN  ...
# ...

# %%
df2[['Profit_tag','Segment']].value_counts()
# Out:
# Profit_tag    Segment
# Less_profit   Consumer       26439
#               Corporate      15385
#               Home Office     9319
# Mid_profit    Consumer          74
#               Corporate         42
#               Home Office       23
# Hight_profit  Consumer           5
#               Corporate          2
#               Home Office        1
# dtype: int64

# %%
df3=df.groupby(['Profit_tag','Segment']).agg({"Row ID":"count"}).rename(columns={'Row ID':'Count_of_rows'}).reset_index()
df3
# Out:
#      Profit_tag      Segment  Count_of_rows
# 0  Hight_profit     Consumer              5
# 1  Hight_profit    Corporate              2
# 2  Hight_profit  Home Office              1
# 3   Less_profit     Consumer          26439
# 4   Less_profit    Corporate          15385
# 5   Less_profit  Home Office           9319
# 6    Mid_profit     Consumer             74
# 7    Mid_profit    Corporate             42
# 8    Mid_profit  Home Office             23

# %%
# segment wise total sales
df4=df.groupby(['Segment']).agg({"Sales":"sum"})

df4
# Out:
#                     Sales
# Segment
# Consumer     6.507949e+06
# Corporate    3.824698e+06
# Home Office  2.309855e+06

# %%
df6=df.groupby(['Segment']).agg({"Sales":"sum",'Row ID':"count","Profit":'min',"Quantity":'max'})
dfel6.rename(columns={'Sales':'Total_sales','Row ID':'Count_of_row','Profit':'Min_Profit','Quantity':'Max_quantity'})
df6_to_excel()
# Out:
#               Total_sales  Count_of_row  Min_Profit  Max_quantity
# Segment
# Consumer     6.507949e+06         26518   -6599.978            14
# Corporate    3.824698e+06         15429   -4088.376            14
# Home Office  2.309855e+06          9343   -3399.980            14

# %%
df7=df.groupby(['Segment'],as_index=False).agg({"Sales":"sum",'Row ID':"count","Sales":'min',"Sales":'max'})
# Out:
#        Segment     Sales  Row ID
# 0     Consumer  13999.96   26518
# 1    Corporate  17499.95   15429
# 2  Home Office  22638.48    9343
