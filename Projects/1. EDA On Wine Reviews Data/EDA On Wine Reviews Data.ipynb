# %% [markdown]
# ## <p style="background-color:yellow;color:black;font-size:120%;text-align:center;border-radius:10px 10px;font-weight:bold;border:0px solid #800080;">Exploratory Data Analysis (EDA) on Wine Reviews Data 🍾 Using Python — Pandas, Numpy, Matplotlib, Seaborn</p>

# %% [raw]
# Problem Statement
# 1. Startups who rejected sharks Offer
#
# 2. Top 10 Most Expensive Wine
#
# 3. Top 10 cheapest wine
#
# 4. Distribution of category
#
# 5. Relationship between Alcohol and Rating
#
# 6. Relationship between Rating & Price
#
# 7. Boxplot of Category and Rating
#
# 8. Boxplot of Category and Alcohol
#
# 9. Boxplot of Category and Price
#
# 10. Correlation

# %%
from IPython.display import IFrame
import datetime
print("Notebook was last executed on:", datetime.date.today().strftime("%Y-%b-%d"), "with Python version")
# !python --version
# Out:
# Notebook was last executed on: 2024-May-11 with Python version
# Python 3.11.7

# %% [markdown]
# # ⚒️ Importing Required Python Libraries

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # ⏳ Check and import dataset (Exploring Dataset)

# %%
wine_data = pd.read_csv(r"C:\Users\ARPAN PANIGRAHI\Downloads\DATA ANALYST-DOCS/wine.csv")
wine_data
# Out:
#                                                      wine  \
# 0       J. Lohr 2000 Hilltop Vineyard Cabernet Sauvign...
# 1                 Antucura 2010 Pinot Noir (Vista Flores)
# 2       Quinta do Portal 1999 Quinta do Portal Reserva...
# 3       Tenuta di Ghizzano 2006 Il Ghizzano Red (Toscana)
# 4       Tenuta San Francesco 2007 Tramonti White (Camp...
# ...                                                   ...
# 323232                  Maddalena 2017 Rosé (Paso Robles)
# 323233           Toscolo 2015  Vernaccia di San Gimignano
# 323234          Domaine G. Metz 2017 Pinot Blanc (Alsace)
# 323235             Huston 2019 Chicken Dinner Red (Idaho)
# 323236                             La Selva 2008  Maremma
#
#                       winery category               designation  \
# 0                    J. Lohr      Red          Hilltop Vineyard
# 1                   Antucura      Red                       NaN
# 2           Quinta do Portal      Red  Quinta do Portal Reserva
# ...

# %% [markdown]
# # 💵 Exploratory Data Analysis (EDA)

# %%
# Top records
wine_data.head()
# Out:
#                                                 wine                winery  \
# 0  J. Lohr 2000 Hilltop Vineyard Cabernet Sauvign...               J. Lohr
# 1            Antucura 2010 Pinot Noir (Vista Flores)              Antucura
# 2  Quinta do Portal 1999 Quinta do Portal Reserva...      Quinta do Portal
# 3  Tenuta di Ghizzano 2006 Il Ghizzano Red (Toscana)    Tenuta di Ghizzano
# 4  Tenuta San Francesco 2007 Tramonti White (Camp...  Tenuta San Francesco
#
#   category               designation                varietal  \
# 0      Red          Hilltop Vineyard      Cabernet Sauvignon
# 1      Red                       NaN              Pinot Noir
# 2      Red  Quinta do Portal Reserva  Red Blends, Red Blends
# 3      Red               Il Ghizzano  Red Blends, Red Blends
# 4    White                  Tramonti             White Blend
#
#                                   appellation alcohol price  rating  \
# 0  Paso Robles, Central Coast, California, US     NaN   $32      87
# ...

# %%
# Bottom records
wine_data.tail()
# Out:
#                                              wine           winery category  \
# 323232          Maddalena 2017 Rosé (Paso Robles)        Maddalena     Rose
# 323233   Toscolo 2015  Vernaccia di San Gimignano          Toscolo    White
# 323234  Domaine G. Metz 2017 Pinot Blanc (Alsace)  Domaine G. Metz    White
# 323235     Huston 2019 Chicken Dinner Red (Idaho)           Huston      Red
# 323236                     La Selva 2008  Maremma         La Selva      Red
#
#            designation                   varietal  \
# 323232             NaN                       Rosé
# 323233             NaN   Vernaccia, Italian White
# 323234             NaN                Pinot Blanc
# 323235  Chicken Dinner     Red Blends, Red Blends
# 323236             NaN  Ciliegiolo, Italian White
#
#                                        appellation alcohol price  rating  \
# 323232  Paso Robles, Central Coast, California, US   12.5%   $18      87
# ...

# %%
# 1. After getting the Data, we need to check the data type of features
# 2. There are few types of features such as numeric, categorical, ordinal, datetime, coordinates

# %%
# To know no. of rows and cols
wine_data.shape
# Out:
# (323237, 11)

# %%
# To know Datatype of columns in a table
wine_data.dtypes
# Out:
# wine           object
# winery         object
# category       object
# designation    object
# varietal       object
# appellation    object
# alcohol        object
# price          object
# rating          int64
# reviewer       object
# review         object
# dtype: object

# %%
# There is only one data i.e. rating is an integer and hence we will get the statistical summary only for this column

# %% [markdown]
# # Descriptive Statistics

# %%
# Statistical Analysis
wine_data.describe()
# Out:
#               rating
# count  323237.000000
# mean       88.585119
# std         3.186544
# min        80.000000
# 25%        86.000000
# 50%        88.000000
# 75%        91.000000
# max       100.000000

# %%
# Datatype information
wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323237 entries, 0 to 323236
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   wine         323237 non-null  object
#  1   winery       323237 non-null  object
#  2   category     323237 non-null  object
#  3   designation  229692 non-null  object
#  4   varietal     302190 non-null  object
#  5   appellation  320630 non-null  object
#  6   alcohol      282216 non-null  object
#  7   price        299282 non-null  object
#  8   rating       323237 non-null  int64
#  9   reviewer     251075 non-null  object
#  10  review       322108 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 27.1+ MB

# %% [markdown]
# # Data Preprocessing

# %%
wine_data.columns
# Out:
# Index(['wine', 'winery', 'category', 'designation', 'varietal', 'appellation',
#        'alcohol', 'price', 'rating', 'reviewer', 'review'],
#       dtype='object')

# %%
wine_data.columns.tolist()
# Out:
# ['wine',
#  'winery',
#  'category',
#  'designation',
#  'varietal',
#  'appellation',
#  'alcohol',
#  'price',
#  'rating',
#  'reviewer',
#  'review']

# %%
# Check for missing values

plt.figure(figsize=(10,5))
sns.heatmap(wine_data.isnull(), yticklabels=False, cbar=True, cmap='mako')
# Out:
# <Axes: >

# %% [markdown]
# # 📊 Data Preparation and Cleaning
# Data cleaning is the process of ensuring that your data is correct and useable by identifying any errors in the data, or missing data by correcting or deleting them. The goal of cleaning operations is to prevent problems caused by missing data that can arise when training a model.

# %%
# Detecting missing values
wine_data.isnull().sum()
# Out:
# wine               0
# winery             0
# category           0
# designation    93545
# varietal       21047
# appellation     2607
# alcohol        41021
# price          23955
# rating             0
# reviewer       72162
# review          1129
# dtype: int64

# %% [raw]
# How to deal with missing data Before trying to deal with missing values in an analysis, we need to understand which variables contain the
# missing values, and we need to examine the patterns of missing values. In the above example, only object type has missing values.
#
# Steps of handling missing values
# 1. Ignore the data row --wine_data.dropna(inplace = True) (but we will get poor performance if the percentage is really high)
# 2. Sometimes, we can delete or drop the row only if all the values are Nan --data.dropna(how='all')
# 3. Instead of deleting the Nan values or missing values, we can fill all the missing values.Missing data can be filled by propagating the
# non-Nan values forward or backward along a Series. Sometimes, Nan value will remain Nan even after forward filling or back filling if a next or
# previous value isn’t available or it is also a Nan value. CODE-- wine_data.fillna(method='ffill') or wine_data.fillna(methods = 'bfill')
# 4. Use a constant value to fill in for missing values. CODE--wine_data.fillna(value=0, inplace=True) (This fills all the null values with 0)
# I believe that its not useful since all the data types we have that are null is object. For filling missing data in an object type data we can
# simply fill with string – ‘missing’ , and we will handle the values in code if necessary. CODE--wine_data['review'].fillna('missing', inplace=True)
# 5. Replacing with mean, median and mode value.Mean is the average number of the data set, median is the middle number and mode is the number that
# occurs most often. Mode can also be used to fill missing data in object type data. we can use
# mode() wine_data['review'].fillna(wine_data['review'].mode()[0], inplace = True)

# %%
# To remove missing values
wine_data['designation'].fillna(wine_data['designation'].mode()[0], inplace = True)
wine_data['varietal'].fillna(wine_data['varietal'].mode()[0], inplace = True)
wine_data['appellation'].fillna(wine_data['appellation'].mode()[0], inplace = True)
wine_data['alcohol'].fillna(wine_data['alcohol'].mode()[0], inplace = True)
wine_data['price'].fillna(wine_data['price'].mode()[0], inplace = True)
wine_data['reviewer'].fillna(wine_data['reviewer'].mode()[0], inplace = True)
wine_data['review'].fillna(wine_data['review'].mode()[0], inplace = True)

# %%
# Check for missing values
wine_data.isnull().sum()
# Out:
# wine           0
# winery         0
# category       0
# designation    0
# varietal       0
# appellation    0
# alcohol        0
# price          0
# rating         0
# reviewer       0
# review         0
# dtype: int64

# %%
wine_data['alcohol']
# Out:
# 0         13.5%
# 1           15%
# 2         13.5%
# 3         13.5%
# 4         13.5%
#           ...
# 323232    12.5%
# 323233    12.5%
# 323234      13%
# 323235    14.3%
# 323236    13.5%
# Name: alcohol, Length: 323237, dtype: object

# %%
# We have to convert this percentage with spaces
wine_data = wine_data.assign(alcohol_num = lambda row: row["alcohol"].replace("%", "", regex=True).astype('float'))

# %%
wine_data1 = wine_data.dropna(subset = ['price'])
price_nums = []
for index, row in wine_data1.iterrows():
    if row["price"].replace("$", "").isdecimal():
        price_nums.append(float(row["price"].replace("$", "")))
    else:
        price_nums.append(np.nan)
wine_data2 = wine_data1.copy()
wine_data2["price_num"] = price_nums
wine_data2 = wine_data2.dropna(subset = ['price_num'])
sns.displot(wine_data2.loc[lambda _wine_data: _wine_data["price_num"] < 125]["price_num"] , bins=30)
plt.show()
# Out:
# C:\Users\ARPAN PANIGRAHI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
wine_data2
# Out:
#                                                      wine  \
# 0       J. Lohr 2000 Hilltop Vineyard Cabernet Sauvign...
# 1                 Antucura 2010 Pinot Noir (Vista Flores)
# 2       Quinta do Portal 1999 Quinta do Portal Reserva...
# 3       Tenuta di Ghizzano 2006 Il Ghizzano Red (Toscana)
# 4       Tenuta San Francesco 2007 Tramonti White (Camp...
# ...                                                   ...
# 323232                  Maddalena 2017 Rosé (Paso Robles)
# 323233           Toscolo 2015  Vernaccia di San Gimignano
# 323234          Domaine G. Metz 2017 Pinot Blanc (Alsace)
# 323235             Huston 2019 Chicken Dinner Red (Idaho)
# 323236                             La Selva 2008  Maremma
#
#                       winery category               designation  \
# 0                    J. Lohr      Red          Hilltop Vineyard
# 1                   Antucura      Red                   Reserve
# 2           Quinta do Portal      Red  Quinta do Portal Reserva
# ...

# %% [markdown]
# # 📊 Finding Insights from the dataset

# %%
# Q1. Top 10 Rated wine according to the rating in Wine Reviews Data

# %%
Top_rated_wine = wine_data2.sort_values('rating',ascending = False).head(10)
Top_rated_wine
# Out:
#                                                      wine  \
# 184528  Patricia Green Cellars 2016 Estate Vineyard Bo...
# 298699             Le Chiuse 2013  Brunello di Montalcino
# 55561     Cardinale 2006 Cabernet Sauvignon (Napa Valley)
# 133162  Philipponnat 2010 Clos des Goisses Extra Brut ...
# 210612               Sloan 2002 Red Wine Red (Rutherford)
# 317921                 Château Ausone 2015  Saint-Émilion
# 124731      Casa Ferreirinha 2008 Barca-Velha Red (Douro)
# 203668            Verité 2007 La Muse Red (Sonoma County)
# 281085  Taylor Fladgate 2017 Vargellas Vinhas Velhas  ...
# 107886                Château Angélus 2016  Saint-Émilion
#
#                         winery     category                    designation  \
# 184528  Patricia Green Cellars          Red  Estate Vineyard Bonshaw Block
# 298699               Le Chiuse          Red                        Reserve
# 55561                Cardinale          Red                        Reserve
# ...

# %%
# In the top 10, mostly we can find red wine to be the highest rated wine then Sparkling and Port/Sherry.

# %%
# Q2. Top 10 Most Expensive Wine

# %%
top_10_expensive_wine = wine_data2.sort_values('price',ascending = False).head(10)
top_10_expensive_wine
# Out:
#                                                      wine  \
# 296196  Arnaud Baillot 2018 Grand Cru  (Romanée-St.-Vi...
# 211946  Château La Mission Haut-Brion 2015  Pessac-Léo...
# 178941  Nuiton-Beaunoy 2015 Les Chaffots Premier Cru  ...
# 105257  Rattalino 2011 Quarantacinque Riserva  (Barbar...
# 204111  Fontanafredda 2015 Proprietà in Fontanafredda ...
# 182186  Château de Tracy 2005 Haute Densité  (Pouilly-...
# 104215  Mailly Grand Cru 2012 L'Intemporelle Brut  (Ch...
# 38794   Chehalem 2014 Statement Pinot Noir (Ribbon Ridge)
# 199133  Les Vins de Vienne 2010 Les Archevêques  (Cond...
# 7248                 Jean Stodden 2009 J Pinot Noir (Ahr)
#
#                                winery   category                 designation  \
# 296196                 Arnaud Baillot        Red                   Grand Cru
# 211946  Château La Mission Haut-Brion      White                     Reserve
# 178941                 Nuiton-Beaunoy        Red    Les Chaffots Premier Cru
# ...

# %%
# Q3. Top 10 cheapest wine

# %%
Top_10_cheapest_wine = wine_data2.sort_values('price',ascending = True).head(10)
Top_10_cheapest_wine
# Out:
#                                                      wine  \
# 167224                             Luis Saenz 2017  Rioja
# 7650    Viña del Pedregal 2017 Kidia Single Vineyard R...
# 130081                      Château Merlet 2015  Bordeaux
# 190990  Terras de Alter 2018 Terra d'Alter Trincadeira...
# 76338   Château Grand Secret 2015 Petit Secret  (Blaye...
# 158187       Bellussi NV Extra Dry  (Prosecco del Veneto)
# 97171   Concannon 2010 Selected Vineyards Cabernet Sau...
# 226771              California's Jewel 2004 Merlot (Lodi)
# 130101     Goats do Roam Wine Co. 2008 Red (Western Cape)
# 130106               Rolling 2009 Shiraz (Central Ranges)
#
#                         winery   category  \
# 167224              Luis Saenz        Red
# 7650         Viña del Pedregal      White
# 130081          Château Merlet        Red
# 190990         Terras de Alter        Red
# 76338     Château Grand Secret      White
# 158187                Bellussi  Sparkling
# ...

# %% [markdown]
# # 💰 Data Visualization

# %% [raw]
# Data visualisation is the graphical representation of information and data. It uses statistical graphics, plots, information graphics and
# other tools to communicate information clearly and efficiently.Here we will focus on commonly used Seaborn visualisation.
# Seaborn is a Python data visualisation library based on matplotlib. It provides a high-level interface for drawing attractive and informative
# statistical graphics. Following are the common used seaborn visualisation :-
#
# 1. Scatter Plot
# 2. Box Plot
# 3. Histogram
# 4. Cat Plot
# 5. Violin Plot
# 6. Pair Plot
# 7. Joint plot
# 8. Heat Map

# %%
# Q4. Distribution of category

# %%
sns.set_style('whitegrid')
sns.pairplot(wine_data2)
plt.show()
# Out:
# C:\Users\ARPAN PANIGRAHI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ARPAN PANIGRAHI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ARPAN PANIGRAHI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.displot(wine_data2,x='category',height=6)
# Out:
# C:\Users\ARPAN PANIGRAHI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Red and White Wine dominates the market.

# %%
wine_data2['rating'].describe()
# Out:
# count    291920.000000
# mean         88.508228
# std           3.171750
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: rating, dtype: float64

# %%
# Q5. Relationship between Alcohol and Rating

# %%
sns.boxplot(x="alcohol_num", y="rating", data=wine_data2) # Alternate
# Out:
# <Axes: xlabel='alcohol_num', ylabel='rating'>

# %%
sns.boxplot(x="alcohol_num", y="rating", data=wine_data2, showfliers=False) # Alternate
# Out:
# <Axes: xlabel='alcohol_num', ylabel='rating'>

# %%
sample = wine_data2.sample(frac=0.01)
sns.regplot(x="alcohol_num", y="rating", data=sample.loc[lambda _df: _df["alcohol_num"] < 20])
# Out:
# <Axes: xlabel='alcohol_num', ylabel='rating'>

# %%
wine_data2.plot(kind = 'scatter',x = 'alcohol_num',y='rating')
plt.title('scatterplot of rating and alcohol')
plt.show()

# %%
# Q6. Relationship between Rating & Price

# %%
sns.jointplot(x="price_num", y="rating",data=wine_data2, kind='reg') # Alternate
# Out:
# C:\Users\ARPAN PANIGRAHI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ARPAN PANIGRAHI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.set_style('whitegrid')
sample = wine_data2.sample(frac=0.01)
sns.regplot(x="price_num", y="rating",data=sample.loc[lambda _wine_data2: _wine_data2["price_num"] < 220])
# Out:
# <Axes: xlabel='price_num', ylabel='rating'>

# %%
wine_data2.plot(kind = 'scatter',x = 'price_num',y='rating')
plt.title('scatterplot of rating and price')
plt.show()

# %%
# Q7. Boxplot of Category and Rating

# %%
sns.boxplot(x="category", y="rating", data=wine_data2)
# Out:
# <Axes: xlabel='category', ylabel='rating'>

# %%
# Q8. Boxplot of Category and Alcohol

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(12,10))
boxplot = sns.boxplot(x="category", y="alcohol_num", data=wine_data2)
boxplot.set_ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
# Q9. Boxplot of Category and Price

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(12,10))
result = sns.boxplot(x="category", y="price_num", data=wine_data2)
result.set_ylim(0,200)
# Out:
# (0.0, 200.0)

# %% [markdown]
# # Correlation

# %%
wine_data2.dtypes
# Out:
# wine            object
# winery          object
# category        object
# designation     object
# varietal        object
# appellation     object
# alcohol         object
# price           object
# rating           int64
# reviewer        object
# review          object
# alcohol_num    float64
# price_num      float64
# dtype: object

# %%
wine_data2.columns
# Out:
# Index(['wine', 'winery', 'category', 'designation', 'varietal', 'appellation',
#        'alcohol', 'price', 'rating', 'reviewer', 'review', 'alcohol_num',
#        'price_num'],
#       dtype='object')

# %%
#  wine_data2 -- ['wine', 'winery', 'category', 'designation', 'varietal', 'appellation',
#        'alcohol', 'price', 'rating', 'reviewer', 'review', 'alcohol_num',
#        'price_num']

# df --> wine_data2['rating','alcohol_num','price_num'] only numeric value in separate table

# ['rating','alcohol_num','price_num'] -- List

df = wine_data2[['rating','alcohol_num','price_num']]
df
# Out:
#         rating  alcohol_num  price_num
# 0           87         13.5       32.0
# 1           85         15.0       17.0
# 2           90         13.5       20.0
# 3           86         13.5       18.0
# 4           85         13.5       21.0
# ...        ...          ...        ...
# 323232      87         12.5       18.0
# 323233      87         12.5       11.0
# 323234      90         13.0       20.0
# 323235      87         14.3       18.0
# 323236      86         13.5       28.0
#
# [315875 rows x 3 columns]

# %%
df.corr()
# Out:
#                rating  alcohol_num  price_num
# rating       1.000000     0.006562   0.359972
# alcohol_num  0.006562     1.000000   0.005893
# price_num    0.359972     0.005893   1.000000

# %%
# To know the range  --- Heatmap
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df.corr(), annot=True, fmt='.2f', linewidths=2)
# Out:
# <Axes: >

# %%
sns.pairplot(df)
# Out:
# C:\Users\ARPAN PANIGRAHI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ARPAN PANIGRAHI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ARPAN PANIGRAHI\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
