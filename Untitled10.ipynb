# %%
import pandas as pd
appolo=pd.read_excel(r"C:\Users\user\OneDrive - Alliance University\Desktop\code\A1.VERTICAL JOIN DATA\A1.VERTICAL_JOIN_DATA.xlsx",sheet_name="MED_APPOLO")
cipla=pd.read_excel(r"C:\Users\user\OneDrive - Alliance University\Desktop\code\A1.VERTICAL JOIN DATA\A1.VERTICAL_JOIN_DATA.xlsx",sheet_name="MED_CIPLA")
geno=pd.read_excel(r"C:\Users\user\OneDrive - Alliance University\Desktop\code\A1.VERTICAL JOIN DATA\A1.VERTICAL_JOIN_DATA.xlsx",sheet_name="MED_GENO")

# %%
appolo.head(2)
# Out:
#    CUSTOMER_ID Company  GENDER  Age STATE_CODE  POST_CODE  NO_OF_TRIPS
# 0   1000032552  APPOLO  Female   26        NSW       2558            6
# 1   1000032554  APPOLO    Male   26        QLD       4575            8

# %%
cipla.head(2)
# Out:
#    CUSTOMER_ID Company  GENDER  Age STATE_CODE  POST_CODE  NO_OF_TRIPS
# 0   1000032553   CIPLA  Female   26        VIC       3136            6
# 1   1000032576   CIPLA  Female   46        QLD       4551            1

# %%
geno.head(2)
# Out:
#    CUSTOMER_ID Company  GENDER  Age STATE_CODE  POST_CODE  NO_OF_TRIPS
# 0   1000032559    GENO  Female   34        VIC       3875            1
# 1   1000032565    GENO  Female   63        NSW       2750            2

# %%
master=pd.concat([cipla,geno,appolo]).reset_index(drop=True)
master
# Out:
#     CUSTOMER_ID Company  GENDER  Age STATE_CODE  POST_CODE  NO_OF_TRIPS
# 0    1000032553   CIPLA  Female   26        VIC       3136            6
# 1    1000032576   CIPLA  Female   46        QLD       4551            1
# 2    1000032592   CIPLA  Female   44        QLD       4519            1
# 3    1000032595   CIPLA  Female   27        NSW       2646            1
# 4    1000032618   CIPLA  Female   39        NSW       2871            6
# 5    1000032622   CIPLA  Female   26        NSW       2820           10
# 6    1000032624   CIPLA    Male   36        NSW       2800            2
# 7    1000032628   CIPLA  Female   39        NSW       2148            1
# 8    1000032631   CIPLA    Male   61        QLD       4301            2
# 9    1000032559    GENO  Female   34        VIC       3875            1
# 10   1000032565    GENO  Female   63        NSW       2750            2
# 11   1000032571    GENO  Female   60        VIC       3351           16
# ...

# %%
religare=pd.read_excel(r"C:\Users\user\OneDrive - Alliance University\Desktop\code\A1.VERTICAL JOIN DATA\A1.VERTICAL_JOIN_DATA.xlsx",sheet_name="MED_RELEGARE")
religare
# Out:
#     CUSTOMER_ID   Company  GENDER  Age STATE_CODE  POST_CODE  VISITS
# 0    1000032549  RELEGARE  Female   54        NSW       2580       1
# 1    1000032561  RELEGARE  Female   51        QLD       4118       3
# 2    1000032563  RELEGARE  Female   48        QLD       4504       2
# 3    1000032568  RELEGARE  Female   24        VIC       3995       1
# 4    1000032577  RELEGARE  Female   56        VIC       3214       1
# 5    1000032580  RELEGARE  Female   64         SA       5066       7
# 6    1000032597  RELEGARE  Female   43        QLD       4074       1
# 7    1000032602  RELEGARE    Male   42        NSW       2480       1
# 8    1000032606  RELEGARE    Male   43        NSW       2650       4
# 9    1000032612  RELEGARE    Male   24        QLD       4818      11
# 10   1000032616  RELEGARE    Male   25        VIC       3152       1

# %%
master=pd.concat([cipla,geno,appolo,religare]).reset_index(drop=True)
master
# Out:
#     CUSTOMER_ID   Company  GENDER  Age STATE_CODE  POST_CODE  NO_OF_TRIPS  \
# 0    1000032553     CIPLA  Female   26        VIC       3136          6.0
# 1    1000032576     CIPLA  Female   46        QLD       4551          1.0
# 2    1000032592     CIPLA  Female   44        QLD       4519          1.0
# 3    1000032595     CIPLA  Female   27        NSW       2646          1.0
# 4    1000032618     CIPLA  Female   39        NSW       2871          6.0
# 5    1000032622     CIPLA  Female   26        NSW       2820         10.0
# 6    1000032624     CIPLA    Male   36        NSW       2800          2.0
# 7    1000032628     CIPLA  Female   39        NSW       2148          1.0
# 8    1000032631     CIPLA    Male   61        QLD       4301          2.0
# 9    1000032559      GENO  Female   34        VIC       3875          1.0
# 10   1000032565      GENO  Female   63        NSW       2750          2.0
# 11   1000032571      GENO  Female   60        VIC       3351         16.0
# ...

# %%
religae_v1=religare.rename(columns={'VISITS':"NO_OF_TRIPS"})
religae_v1
# Out:
#     CUSTOMER_ID   Company  GENDER  Age STATE_CODE  POST_CODE  NO_OF_TRIPS
# 0    1000032549  RELEGARE  Female   54        NSW       2580            1
# 1    1000032561  RELEGARE  Female   51        QLD       4118            3
# 2    1000032563  RELEGARE  Female   48        QLD       4504            2
# 3    1000032568  RELEGARE  Female   24        VIC       3995            1
# 4    1000032577  RELEGARE  Female   56        VIC       3214            1
# 5    1000032580  RELEGARE  Female   64         SA       5066            7
# 6    1000032597  RELEGARE  Female   43        QLD       4074            1
# 7    1000032602  RELEGARE    Male   42        NSW       2480            1
# 8    1000032606  RELEGARE    Male   43        NSW       2650            4
# 9    1000032612  RELEGARE    Male   24        QLD       4818           11
# 10   1000032616  RELEGARE    Male   25        VIC       3152            1

# %%
master=pd.concat([cipla,geno,appolo,religae_v1]).reset_index(drop=True)
master
# Out:
#     CUSTOMER_ID   Company  GENDER  Age STATE_CODE  POST_CODE  NO_OF_TRIPS
# 0    1000032553     CIPLA  Female   26        VIC       3136            6
# 1    1000032576     CIPLA  Female   46        QLD       4551            1
# 2    1000032592     CIPLA  Female   44        QLD       4519            1
# 3    1000032595     CIPLA  Female   27        NSW       2646            1
# 4    1000032618     CIPLA  Female   39        NSW       2871            6
# 5    1000032622     CIPLA  Female   26        NSW       2820           10
# 6    1000032624     CIPLA    Male   36        NSW       2800            2
# 7    1000032628     CIPLA  Female   39        NSW       2148            1
# 8    1000032631     CIPLA    Male   61        QLD       4301            2
# 9    1000032559      GENO  Female   34        VIC       3875            1
# 10   1000032565      GENO  Female   63        NSW       2750            2
# 11   1000032571      GENO  Female   60        VIC       3351           16
# ...

# %%
gsk=pd.read_excel(r"C:\Users\user\OneDrive - Alliance University\Desktop\code\A1.VERTICAL JOIN DATA\A1.VERTICAL_JOIN_DATA.xlsx",sheet_name="MED_GSK")
gsk
# Out:
#     CUSTOMER_ID Company  GENDER  Age STATE_CODE  POST_CODE  NO_OF_TRIPS  \
# 0    1000032550     GSK    Male   35        VIC       3043            2
# 1    1000032551     GSK    Male   34        VIC       3190           12
# 2    1000032557     GSK  Female   28        QLD       4814            1
# 3    1000032572     GSK  Female   42        NSW       2533           18
# 4    1000032574     GSK  Female   25        NSW       2077            7
# 5    1000032585     GSK  Female   51         NT        850            3
# 6    1000032586     GSK    Male   27        NSW       2680            1
# 7    1000032589     GSK    Male   27         SA       5118            3
# 8    1000032590     GSK    Male   22        NSW       2650            1
# 9    1000032610     GSK    Male   73        NSW       2075           10
# 10   1000032615     GSK  Female   45         SA       5095            3
#
#              TOWN  Spent amount
# 0    Willow Grove        160.98
# 1       mona vale        289.10
# ...

# %%
master=pd.concat([cipla,geno,appolo,religae_v1,gsk]).reset_index(drop=True)
master
# Out:
#     CUSTOMER_ID   Company  GENDER  Age STATE_CODE  POST_CODE  NO_OF_TRIPS  \
# 0    1000032553     CIPLA  Female   26        VIC       3136            6
# 1    1000032576     CIPLA  Female   46        QLD       4551            1
# 2    1000032592     CIPLA  Female   44        QLD       4519            1
# 3    1000032595     CIPLA  Female   27        NSW       2646            1
# 4    1000032618     CIPLA  Female   39        NSW       2871            6
# 5    1000032622     CIPLA  Female   26        NSW       2820           10
# 6    1000032624     CIPLA    Male   36        NSW       2800            2
# 7    1000032628     CIPLA  Female   39        NSW       2148            1
# 8    1000032631     CIPLA    Male   61        QLD       4301            2
# 9    1000032559      GENO  Female   34        VIC       3875            1
# 10   1000032565      GENO  Female   63        NSW       2750            2
# 11   1000032571      GENO  Female   60        VIC       3351           16
# ...

# %%
horizontal join

# %%
stu_table1=pd.read_excel(r"C:\Users\user\OneDrive - Alliance University\Desktop\code\A1.VERTICAL JOIN DATA\A1.VERTICAL_JOIN_DATA.xlsx",sheet_name="STU_SCORE1")
stu_table2=pd.read_excel(r"C:\Users\user\OneDrive - Alliance University\Desktop\code\A1.VERTICAL JOIN DATA\A1.VERTICAL_JOIN_DATA.xlsx",sheet_name="STU_SCORE2")

# %%
stu_table1
# Out:
#    STU_NAME  SUBJECT  SCORE
# 0      SIMI      SAS    453
# 1      SIMI        R    743
# 2      SIMI   PYTHON    282
# 3      SIMI    EXCEL    250
# 4     SUDIP        R    598
# 5     SUDIP  TABLEAU    459
# 6     SUDIP   PYTHON    776
# 7     SUDIP      VBA    266
# 8     SASHI    EXCEL    282
# 9     SASHI      VBA    590
# 10    SASHI      SQL    456

# %%
stu_table2
# Out:
#    STU_NAME   SUBJECT  SCORE
# 0      SIMI       SAS    453
# 1      SIMI         R    743
# 2      SIMI    PYTHON    282
# 3      SIMI   TABLEAU    450
# 4   RUCHIKA         R    708
# 5   RUCHIKA   TABLEAU    704
# 6   RUCHIKA     EXCEL    562
# 7   RUCHIKA  QLIKVIEW    438
# 8   PRABHAT     EXCEL    751
# 9   PRABHAT       VBA    749
# 10  PRABHAT       SQL    880

# %%
master=pd.concat([stu_table1,stu_table2]).reset_index(drop=True)
master
# Out:
#    STU_NAME   SUBJECT  SCORE
# 0      SIMI       SAS    453
# 1      SIMI         R    743
# 2      SIMI    PYTHON    282
# 3      SIMI     EXCEL    250
# 4     SUDIP         R    598
# 5     SUDIP   TABLEAU    459
# 6     SUDIP    PYTHON    776
# 7     SUDIP       VBA    266
# 8     SASHI     EXCEL    282
# 9     SASHI       VBA    590
# 10    SASHI       SQL    456
# 11     SIMI       SAS    453
# 12     SIMI         R    743
# 13     SIMI    PYTHON    282
# 14     SIMI   TABLEAU    450
# 15  RUCHIKA         R    708
# 16  RUCHIKA   TABLEAU    704
# 17  RUCHIKA     EXCEL    562
# 18  RUCHIKA  QLIKVIEW    438
# 19  PRABHAT     EXCEL    751
# 20  PRABHAT       VBA    749
# 21  PRABHAT       SQL    880

# %%
master.drop_duplicates().reset_index(drop=True)
# Out:
#    STU_NAME   SUBJECT  SCORE
# 0      SIMI       SAS    453
# 1      SIMI         R    743
# 2      SIMI    PYTHON    282
# 3      SIMI     EXCEL    250
# 4     SUDIP         R    598
# 5     SUDIP   TABLEAU    459
# 6     SUDIP    PYTHON    776
# 7     SUDIP       VBA    266
# 8     SASHI     EXCEL    282
# 9     SASHI       VBA    590
# 10    SASHI       SQL    456
# 11     SIMI   TABLEAU    450
# 12  RUCHIKA         R    708
# 13  RUCHIKA   TABLEAU    704
# 14  RUCHIKA     EXCEL    562
# 15  RUCHIKA  QLIKVIEW    438
# 16  PRABHAT     EXCEL    751
# 17  PRABHAT       VBA    749
# 18  PRABHAT       SQL    880
